# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation

#open CSV
completedDF =  pd.read_csv('../data/LL24_InProgress_bbl.csv')
completedDF = completedDF[['BBL', 'Site']]
completedDF['BBL'] = completedDF['BBL'].astype(str)
completedDF.head()
# Out:
#           BBL             Site
# 0  1003540080             M025
# 1  1003550010             M020
# 2  1000940025  100 Gold Street
# 3  1003560100             M188
# 4  1003870001             M064

# %%
#open CSV
df2015 = pd.read_csv('../data/benchmark_2017.csv', low_memory=False)
df2015.head()
# Out:
#    Order  Property Id                   Property Name  Parent Property Id  \
# 0      1      4593574           The Argonaut Building                 NaN
# 1      2      6224375                 Operative Cakes                 NaN
# 2      3      2967701  Cathedral Preparatory Seminary                 NaN
# 3      4      4898531                 The Nomad Hotel                 NaN
# 4      5      2917939          10 West 27 Street Corp                 NaN
#
#   Parent Property Name        BBL - 10 digits  \
# 0                  NaN             1010287502
# 1                  NaN  2005600062;2055600062
# 2                  NaN             4018720007
# 3                  NaN             1008290050
# 4                  NaN             1008280053
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1010287502
# 1                      2-00560-0062;2-05560-0062
# 2                                   4-01872-0007
# ...

# %%
df2015 = df2015[['BBL - 10 digits', 'Total GHG Emissions (Metric Tons CO2e)', 'Latitude', 'Longitude']]
df2015 = df2015.dropna()
df2015 = df2015.rename(columns={"BBL - 10 digits": "BBL"})
df2015.head()
# Out:
#                      BBL Total GHG Emissions (Metric Tons CO2e)   Latitude  \
# 0             1010287502                                  732.4  40.765949
# 1  2005600062;2055600062                                  284.8  40.821209
# 2             4018720007                                  164.5  40.736195
# 3             1008290050                               1,150.20  40.744996
# 4             1008280053                                  273.4  40.744310
#
#    Longitude
# 0 -73.981073
# 1 -73.837894
# 2 -73.869956
# 3 -73.988773
# 4 -73.988924

# %%
df2015['BBL'] = df2015['BBL'].map(lambda y: y.replace(',', ''))
df2015.head()
# Out:
#           BBL Total GHG Emissions (Metric Tons CO2e)   Latitude  Longitude
# 0  1013160001                               6,962.20  40.750791 -73.973963
# 1  1021380040                              55,870.40  40.841402 -73.942568
# 2  1021380030                                      0  40.840427 -73.940249
# 3  1021390001                                      0  40.840746 -73.942854
# 4  1021390085                                      0  40.841559 -73.942528

# %%
df2015['BBL'] = df2015['BBL'].astype(str)

# %%
mergedDF = pd.merge(completedDF, df2015, how='inner', on=['BBL'])
mergedDF
# Out:
#             BBL             Site Total GHG Emissions (Metric Tons CO2e)  \
# 0    1003540080             M025                                  733.2
# 1    1000940025  100 Gold Street                               4,531.60
# 2    1003560100             M188                                  474.7
# 3    1003870001             M064                                  655.3
# 4    1007420007             M440                               1,296.10
# ..          ...              ...                                    ...
# 111  3074250002             K495                                  1,602
# 112  5002760007             R045                                  420.5
# 113  5033550070     Ocean Breeze                               1,298.90
# 114  5067960044             R003                                  326.1
# 115  5065440001             R007                                  676.5
#
#       Latitude  Longitude
# 0    40.720581 -73.985645
# 1    40.710353 -74.004007
# ...
